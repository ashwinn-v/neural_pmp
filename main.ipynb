# %% [markdown]
# **CONTINUOUS-TIME MOUNTAIN CAR EXPERIMENT**

# %%
from train import train
train('mountain_car', num_examples=640, mode=1, num_examples_phase2=1, 
              retrain_phase1=True, retrain_phase2=True)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Training environment mountain_car:
#
#
# Training phase 1...
#
# Epoch 1:
# Average loss for 20th iteration is: 1.4119350051958164
# Average loss for 40th iteration is: 0.7988619984249221
#
# Epoch 2:
# Average loss for 20th iteration is: 0.5778606939810482
# Average loss for 40th iteration is: 0.5276916452791403
#
# Epoch 3:
# Average loss for 20th iteration is: 0.44720503279722024
# Average loss for 40th iteration is: 0.31521076234403056
#
# Epoch 4:
# Average loss for 20th iteration is: 0.2326871366029847
# Average loss for 40th iteration is: 0.15670978367882343
#
# Epoch 5:
# Average loss for 20th iteration is: 0.11109811680108077
# Average loss for 40th iteration is: 0.10760735495156107
#
# Training phase 2...
#
# Epoch 1:
# Average loss for 20th iteration is: 0.535971887409687
# Average loss for 40th iteration is: 0.2822571597993374
#
# Epoch 2:
# Average loss for 20th iteration is: 0.14977727010846137
# Average loss for 40th iteration is: 0.1027375940233469
#
# Epoch 3:
# Average loss for 20th iteration is: 0.08607601802796125
# Average loss for 40th iteration is: 0.08361494448035955
#
# Epoch 4:
# Average loss for 20th iteration is: 0.07728709075599909
# Average loss for 40th iteration is: 0.07688049897551537
#
# Epoch 5:
# Average loss for 20th iteration is: 0.07729253377765417
# Average loss for 40th iteration is: 0.07051527015864849
#
# Epoch 6:
# Average loss for 20th iteration is: 0.07385085690766573
# Average loss for 40th iteration is: 0.07399551160633563
#
# Epoch 7:
# Average loss for 20th iteration is: 0.07191792353987694
# Average loss for 40th iteration is: 0.07329178117215633
#
# Epoch 8:
# Average loss for 20th iteration is: 0.0723572064191103
# Average loss for 40th iteration is: 0.07427209280431271
#
# Epoch 9:
# Average loss for 20th iteration is: 0.07022924479097128
# Average loss for 40th iteration is: 0.0708164332434535
#
# Epoch 10:
# Average loss for 20th iteration is: 0.07289163637906312
# Average loss for 40th iteration is: 0.07442856971174479
#
# Done training. Saving model...
# Done.

# %%
import numpy as np
from test import benchmarks

benchmarks(env_name='mountain_car', num_trajs=2000, time_steps=list(np.arange(0, 1.0, 0.05)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from test import benchmarks
#       4 benchmarks(env_name='mountain_car', num_trajs=2000, time_steps=list(np.arange(0, 1.0, 0.05)))
#
# ImportError: cannot import name 'benchmarks' from 'test' (/mnt/data/ashwin/miniconda3/envs/sketchy/lib/python3.9/test/__init__.py)

# %%
from test import visualize
import numpy as np
visualize(env_name='mountain_car', time_steps=list(np.arange(0, 1.0, 0.05)), test_trained=False, phase2=False)
visualize(env_name='mountain_car', time_steps=list(np.arange(0, 1.0, 0.05)), test_trained=True, phase2=False)
visualize(env_name='mountain_car', time_steps=list(np.arange(0, 1.0, 0.05)), test_trained=True, phase2=True)
# Out:
# Test untrained mountain_car:
# Done finding trajectory...
# Test mountain_car:
# Done finding trajectory...
# Test phase 2 for mountain_car:
# Done finding trajectory...

# %% [markdown]
# **CONTINUOUS-TIME CARTPOLE EXPERIMENT**

# %%
from train import train
train('cartpole', num_examples=640, mode=1, num_examples_phase2=1,
              retrain_phase1=True, retrain_phase2=True)
# Out:
# Training environment cartpole:
#
#
# Training phase 1...
#
# Epoch 1:
# Average loss for 20th iteration is: 1473.1422036515723
# Average loss for 40th iteration is: 14748.60641720987
# Average loss for 60th iteration is: 31543.808654439734
# Average loss for 80th iteration is: 10871.387052029808
# Average loss for 100th iteration is: 4841.073232593097
#
# Epoch 2:
# Average loss for 20th iteration is: 3929.3592527568917
# Average loss for 40th iteration is: 3118.4352890666914
# Average loss for 60th iteration is: 2294.270058197402
# Average loss for 80th iteration is: 1758.5891034804135
# Average loss for 100th iteration is: 1406.1811826321111
#
# Epoch 3:
# Average loss for 20th iteration is: 1081.8193250442348
# Average loss for 40th iteration is: 830.7894082885135
# Average loss for 60th iteration is: 650.4418538299373
# Average loss for 80th iteration is: 515.9994087312012
# Average loss for 100th iteration is: 392.9820490593083
#
# Epoch 4:
# Average loss for 20th iteration is: 317.96998253213764
# Average loss for 40th iteration is: 252.19754652029457
# Average loss for 60th iteration is: 194.11427936614416
# Average loss for 80th iteration is: 144.474091772185
# Average loss for 100th iteration is: 113.27963766130691
#
# Epoch 5:
# Average loss for 20th iteration is: 77.09144332328232
# Average loss for 40th iteration is: 52.154765279669206
# Average loss for 60th iteration is: 39.51847857350184
# Average loss for 80th iteration is: 18.913538342257905
# Average loss for 100th iteration is: 13.815589352879254
#
# Training phase 2...
#
# Epoch 1:
# Average loss for 20th iteration is: 0.021809603786095977
# Average loss for 40th iteration is: 0.001709408889291808
# Average loss for 60th iteration is: 0.00040534958097850906
# Average loss for 80th iteration is: 0.00019796711931121535
# Average loss for 100th iteration is: 0.00017460610179114154
#
# Epoch 2:
# Average loss for 20th iteration is: 0.00014856743255222681
# Average loss for 40th iteration is: 0.0001378890698106261
# Average loss for 60th iteration is: 0.0001283692126889946
# Average loss for 80th iteration is: 0.00011393153326935134
# Average loss for 100th iteration is: 0.00010162227263208479
#
# Epoch 3:
# Average loss for 20th iteration is: 9.330406246590428e-05
# Average loss for 40th iteration is: 8.870405035850126e-05
# Average loss for 60th iteration is: 8.166805891960394e-05
# Average loss for 80th iteration is: 8.076273661572486e-05
# Average loss for 100th iteration is: 7.252324285218492e-05
#
# Epoch 4:
# Average loss for 20th iteration is: 6.0670511084026656e-05
# Average loss for 40th iteration is: 6.459357427957002e-05
# Average loss for 60th iteration is: 5.801541865366744e-05
# Average loss for 80th iteration is: 5.372265077312477e-05
# Average loss for 100th iteration is: 4.898156530543929e-05
#
# Epoch 5:
# Average loss for 20th iteration is: 4.76419874757994e-05
# Average loss for 40th iteration is: 4.846485953748925e-05
# Average loss for 60th iteration is: 4.476082722248975e-05
# Average loss for 80th iteration is: 4.2004167517006864e-05
# Average loss for 100th iteration is: 4.208345035294769e-05
#
# Epoch 6:
# Average loss for 20th iteration is: 3.918895308743231e-05
# Average loss for 40th iteration is: 3.886494778271299e-05
# Average loss for 60th iteration is: 3.766179006561288e-05
# Average loss for 80th iteration is: 3.712927091328311e-05
# Average loss for 100th iteration is: 3.45186938830011e-05
#
# Epoch 7:
# Average loss for 20th iteration is: 3.503607458696933e-05
# Average loss for 40th iteration is: 3.441479948378401e-05
# Average loss for 60th iteration is: 3.523434243106749e-05
# Average loss for 80th iteration is: 3.464146520855138e-05
# Average loss for 100th iteration is: 3.180623198204557e-05
#
# Epoch 8:
# Average loss for 20th iteration is: 2.9743402865278768e-05
# Average loss for 40th iteration is: 2.8258735346753384e-05
# Average loss for 60th iteration is: 3.171360795022338e-05
# Average loss for 80th iteration is: 3.155021404381842e-05
# Average loss for 100th iteration is: 3.022505134140374e-05
#
# Epoch 9:
# Average loss for 20th iteration is: 2.906107647504541e-05
# Average loss for 40th iteration is: 3.020810645466554e-05
# Average loss for 60th iteration is: 3.070245602430077e-05
# Average loss for 80th iteration is: 2.8302610735408963e-05
# Average loss for 100th iteration is: 2.927202704086085e-05
#
# Epoch 10:
# Average loss for 20th iteration is: 2.8924695652676746e-05
# Average loss for 40th iteration is: 2.7535399476619203e-05
# Average loss for 60th iteration is: 2.8127400764788035e-05
# Average loss for 80th iteration is: 2.9307379554666114e-05
# Average loss for 100th iteration is: 2.6218386574328177e-05
#
# Done training. Saving model...
# Done.

# %%
import numpy as np
from test import benchmarks

benchmarks(env_name='cartpole', num_trajs=2000, time_steps=list(np.arange(0, 10.0, 0.05)))
# Out:
# Done finding trajectory...
# Done finding trajectory...
# Done finding trajectory...
# Random Hamiltonian: 0.19240576542541385
# NeuralPMP-phase 1: 0.021208660070222287
# NeuralPMP: 0.020248912219896345

# %%
import os
os.chdir('/mnt/data/ashwin/neural_pmp')

# %%
from test import visualize
import numpy as np
# visualize(env_name='cartpole', time_steps=list(np.arange(0, 10.0, 0.05)), test_trained=False, phase2=False)
# visualize(env_name='cartpole', time_steps=list(np.arange(0, 10.0, 0.05)), test_trained=True, phase2=False)
# visualize(env_name='cartpole', time_steps=list(np.arange(0, 10.0, 0.05)), test_trained=True, phase2=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from test import visualize
#       2 import numpy as np
#       3 # visualize(env_name='cartpole', time_steps=list(np.arange(0, 10.0, 0.05)), test_trained=False, phase2=False)
#       4 # visualize(env_name='cartpole', time_steps=list(np.arange(0, 10.0, 0.05)), test_trained=True, phase2=False)
#       5 # visualize(env_name='cartpole', time_steps=list(np.arange(0, 10.0, 0.05)), test_trained=True, phase2=True)
#
# ImportError: cannot import name 'visualize' from 'test' (/mnt/data/ashwin/miniconda3/envs/sketchy/lib/python3.9/test/__init__.py)

# %% [markdown]
# **CONTINUOUS-TIME PENDULUM EXPERIMENT**

# %%
from train import train
train('pendulum', num_examples=640, mode=1, num_examples_phase2=1,
              retrain_phase1=True, retrain_phase2=True)
# Out:
# Training environment pendulum:
#
#
# Training phase 1...
#
# Epoch 1:
# Average loss for 20th iteration is: 16.387269616917337
# Average loss for 40th iteration is: 13.275484942325239
#
# Epoch 2:
# Average loss for 20th iteration is: 10.852525753947457
# Average loss for 40th iteration is: 7.416209409690038
#
# Epoch 3:
# Average loss for 20th iteration is: 3.5161554604366914
# Average loss for 40th iteration is: 1.6465535698512734
#
# Epoch 4:
# Average loss for 20th iteration is: 1.2917960247235776
# Average loss for 40th iteration is: 0.7576366286131775
#
# Epoch 5:
# Average loss for 20th iteration is: 0.5790762939145376
# Average loss for 40th iteration is: 0.49988511690968307
#
# Training phase 2...
#
# Epoch 1:
# Average loss for 20th iteration is: 0.3762856811285019
# Average loss for 40th iteration is: 0.22473222985863686
#
# Epoch 2:
# Average loss for 20th iteration is: 0.12610361240804197
# Average loss for 40th iteration is: 0.06348342224955558
#
# Epoch 3:
# Average loss for 20th iteration is: 0.032060866616666316
# Average loss for 40th iteration is: 0.023920813109725714
#
# Epoch 4:
# Average loss for 20th iteration is: 0.022376262489706276
# Average loss for 40th iteration is: 0.020058893505483864
#
# Epoch 5:
# Average loss for 20th iteration is: 0.019224989926442504
# Average loss for 40th iteration is: 0.019453208660706878
#
# Epoch 6:
# Average loss for 20th iteration is: 0.02017323416657746
# Average loss for 40th iteration is: 0.018593128584325314
#
# Epoch 7:
# Average loss for 20th iteration is: 0.019066703971475363
# Average loss for 40th iteration is: 0.018059509387239814
#
# Epoch 8:
# Average loss for 20th iteration is: 0.01939603602513671
# Average loss for 40th iteration is: 0.017682166816666723
#
# Epoch 9:
# Average loss for 20th iteration is: 0.018610436795279385
# Average loss for 40th iteration is: 0.018697500182315707
#
# Epoch 10:
# Average loss for 20th iteration is: 0.018320328556001186
# Average loss for 40th iteration is: 0.01742953439243138
#
# Done training. Saving model...
# Done.

# %%
import numpy as np
from test import benchmarks

benchmarks(env_name='pendulum', num_trajs=2000, time_steps=list(np.arange(0, 1.0, 0.05)))
# Out:
# Done finding trajectory...
# Done finding trajectory...
# Done finding trajectory...
# Random Hamiltonian: 2.374609854698181
# NeuralPMP-phase 1: 0.17012485802918673
# NeuralPMP: 0.19864482815563678
